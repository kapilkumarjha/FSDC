# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('google_cleaned.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %%
df.describe().T
# Out:
#             count          mean           std     min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.0    38.0    2094.0
# Size       9145.0  3.702452e+04  9.887731e+04    10.0  5600.0   15000.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.0     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.0     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.0     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.0  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        34000.0  1.020000e+06
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# year         2018.0  2.018000e+03

# %%
df.describe(include='all')
# Out:
#            App Category       Rating       Reviews          Size  \
# count    10840    10840  9366.000000  1.084000e+04  9.145000e+03
# unique    9659       33          NaN           NaN           NaN
# top     ROBLOX   FAMILY          NaN           NaN           NaN
# freq         9     1972          NaN           NaN           NaN
# mean       NaN      NaN     4.191757  4.441529e+05  3.702452e+04
# std        NaN      NaN     0.515219  2.927761e+06  9.887731e+04
# min        NaN      NaN     1.000000  0.000000e+00  1.000000e+01
# 25%        NaN      NaN     4.000000  3.800000e+01  5.600000e+03
# 50%        NaN      NaN     4.300000  2.094000e+03  1.500000e+04
# 75%        NaN      NaN     4.500000  5.477550e+04  3.400000e+04
# max        NaN      NaN     5.000000  7.815831e+07  1.020000e+06
#
#             Installs   Type         Price Content Rating Genres Last Updated  \
# count   1.084000e+04  10839  10840.000000          10840  10840        10840
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploring the data

# %% [markdown]
# ### Segregate categorical features and numeric features

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
 num_df = df[numeric_features]

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
cat_df = df[categorical_features]

# %%
df['App'].value_counts(normalize=True)*100
# Out:
# ROBLOX                                           0.086898
# 8 Ball Pool                                      0.067587
# Bubble Shooter                                   0.057932
# Helix Jump                                       0.057932
# Zombie Catchers                                  0.057932
#                                                    ...
# Popsicle Launcher for Android P 9.0 launcher     0.009655
# PixelLab - Text on pictures                      0.009655
# P Launcher for Android™ 9.0                      0.009655
# Pacify (Android P theme) - Theme for Xperia™     0.009655
# iHoroscope - 2018 Daily Horoscope & Astrology    0.009655
# Name: App, Length: 9659, dtype: float64

# %%
len(df['App'].value_counts())
# Out:
# 9659

# %%
num_df
# Out:
#        Rating  Reviews     Size  Installs  Price  day  month  year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [10357 rows x 8 columns]

# %%
#check distribution of numeric features
sns.kdeplot(num_df['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
for feature in numeric_features:
    sns.kdeplot(num_df[feature])
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.title('Numerical features')
    plt.show()

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
cat_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
cat_df['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
cat_df['Content Rating'].value_counts()
# Out:
# Everyone           8382
# Teen               1146
# Mature 17+          447
# Everyone 10+        377
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
cat_df['Genres'].value_counts()
# Out:
# Tools                                842
# Entertainment                        588
# Education                            527
# Business                             427
# Medical                              408
#                                     ...
# Parenting;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Lifestyle;Pretend Play                 1
# Tools;Education                        1
# Strategy;Creativity                    1
# Name: Genres, Length: 119, dtype: int64

# %%
sns.countplot(cat_df['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(cat_df['Content Rating'])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
# categorical columns
plt.figure(figsize=(40, 35))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating','Category']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
cat_df['Category'].value_counts().plot.pie(figsize=(15,15))
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
category=pd.DataFrame(cat_df['Category'].value_counts())

# %%
category.head(10)
# Out:
#                  Category
# FAMILY               1943
# GAME                 1121
# TOOLS                 843
# BUSINESS              427
# MEDICAL               408
# PRODUCTIVITY          407
# PERSONALIZATION       388
# LIFESTYLE             373
# COMMUNICATION         366
# FINANCE               360

# %%
category.rename(columns={"Category":"Count"},inplace=True)

# %%
category.head(10)
# Out:
#                  Count
# FAMILY            1943
# GAME              1121
# TOOLS              843
# BUSINESS           427
# MEDICAL            408
# PRODUCTIVITY       407
# PERSONALIZATION    388
# LIFESTYLE          373
# COMMUNICATION      366
# FINANCE            360

# %%
plt.figure(figsize=(20, 20))
sns.barplot(x=category.index[:10],y='Count',data=category[:10])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
num_df.head()
# Out:
#    Rating  Reviews     Size  Installs  Price  day  month  year
# 0     4.1      159  19000.0     10000    0.0    7      1  2018
# 1     3.9      967  14000.0    500000    0.0   15      1  2018
# 2     4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3     4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4     4.3      967   2800.0    100000    0.0   20      6  2018

# %% [markdown]
# ### which category has largest number of installation?

# %%
df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False)
# Out:
# Category
# GAME                   31544024415
# COMMUNICATION          24152276251
# SOCIAL                 12513867902
# PRODUCTIVITY           12463091369
# TOOLS                  11452771915
# FAMILY                 10041692505
# PHOTOGRAPHY             9721247655
# TRAVEL_AND_LOCAL        6361887146
# VIDEO_PLAYERS           6222002720
# NEWS_AND_MAGAZINES      5393217760
# SHOPPING                2573348785
# ENTERTAINMENT           2455660000
# PERSONALIZATION         2074494782
# BOOKS_AND_REFERENCE     1916469576
# SPORTS                  1528574498
# HEALTH_AND_FITNESS      1361022512
# BUSINESS                 863664865
# FINANCE                  770348734
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                534823539
# EDUCATION                533952000
# WEATHER                  426100520
# FOOD_AND_DRINK           257898751
# DATING                   206536107
# HOUSE_AND_HOME           125212461
# ART_AND_DESIGN           124338100
# ...

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10)
# Out:
# Category
# GAME                  31544024415
# COMMUNICATION         24152276251
# SOCIAL                12513867902
# PRODUCTIVITY          12463091369
# TOOLS                 11452771915
# FAMILY                10041692505
# PHOTOGRAPHY            9721247655
# TRAVEL_AND_LOCAL       6361887146
# VIDEO_PLAYERS          6222002720
# NEWS_AND_MAGAZINES     5393217760
# Name: Installs, dtype: int64

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='Installs'>

# %%
df.groupby(['Category'])['Installs'].sum().nlargest(10).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# # Task

# %% [markdown]
# ### how many app are there in google play store which get 5 ratings?

# %%
 df[df["Rating"] == 5.0]
# Out:
#                                               App   Category  Rating  Reviews  \
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0       15
# 612                 American Girls Mobile Numbers     DATING     5.0        5
# 615                                  Awake Dating     DATING     5.0        2
# 633                         Spine- The dating app     DATING     5.0        5
# 636    Girls Live Talk - Free Text and Video Chat     DATING     5.0        6
# ...                                           ...        ...     ...      ...
# 10720                           Mad Dash Fo' Cash       GAME     5.0       14
# 10741                       GKPB FP Online Church  LIFESTYLE     5.0       32
# 10775                            Monster Ride Pro       GAME     5.0        1
# 10819                             Fr. Daoud Lamei     FAMILY     5.0       22
# 10836            Fr. Mike Schmitz Audio Teachings     FAMILY     5.0        4
#
# ...

# %% [markdown]
# ### From the above plot, we will get the app list which get 5 ratings in google play store.

# %% [markdown]
# ### Does size of any application has any impact on its popularity?

# %%
sns.scatterplot(data=df, x="App", y="Size")
# Out:
# <AxesSubplot:xlabel='App', ylabel='Size'>

# %% [markdown]
# ### From the above plot, we saw as the size increase of app popularity also increase

# %% [markdown]
# ### what are the top 5 most installed apps in each popular category?

# %%
y = df['Category'].value_counts().index
x = df['Category'].value_counts()
xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.figure(figsize=(18,13))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %% [markdown]
# ### So there are all total of 33 categories in the dataset from the above output we can come to the conclusion that in the play store most of the apps are under Family & Game category and least are of Beauty & Comics Category

# %%
def findtop5incategory(str):
    str = str.upper()
    top5 = df[df['Category'] == str]
    top5apps = top5.sort_values(by='Installs', ascending=False).head(5)
    # Top_Apps_in_art_and_design
    plt.figure(figsize=(15,12))
    plt.title('Top 5 Installed Apps',size = 20);    
    graph = sns.barplot(x = top5apps.App, y = top5apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right')

# %%
findtop5incategory('BEAUTY')

# %% [markdown]
# ### From the above graph, we can see that in the BEAUTY category,these top 5 most Apps install in each popular category . In the same way by passing different category names to the function, we can get the top 5 installed apps

# %% [markdown]
# ### which category app users are reviewing the most?

# %%
Apps_with_Highest_rev = df.sort_values(by='Reviews', ascending=False).head(20)

# %%
Apps_with_Highest_rev
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 3943                                  Facebook         SOCIAL     4.1
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 2604                                 Instagram         SOCIAL     4.5
# 2545                                 Instagram         SOCIAL     4.5
# 3909                                 Instagram         SOCIAL     4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 1879                            Clash of Clans           GAME     4.6
# 1670                            Clash of Clans           GAME     4.6
# 3986                            Clash of Clans         FAMILY     4.6
# ...

# %% [markdown]
# ### which kind of app user are downloading the most free/paid?

# %%
top5PaidApps = df[df['Type'] == 'Paid'].sort_values(by='Installs',ascending=False).head(5)
# top10PaidApps

# %%
top5PaidApps
# Out:
#                           App         Category  Rating  Reviews     Size  \
# 2241                Minecraft           FAMILY     4.5  2376564      NaN
# 4347                Minecraft           FAMILY     4.5  2375336      NaN
# 4034            Hitman Sniper             GAME     4.6   408292  29000.0
# 3403    Beautiful Widgets Pro  PERSONALIZATION     4.2    97890  14000.0
# 5631  Five Nights at Freddy's             GAME     4.6   100805  50000.0
#
#       Installs  Type  Price Content Rating                     Genres  \
# 2241  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 4347  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 4034  10000000  Paid   0.99     Mature 17+                     Action
# 3403   1000000  Paid   2.49       Everyone            Personalization
# 5631   1000000  Paid   2.99           Teen                     Action
#
#      Last Updated Current Ver         Android Ver  day  month  year
# ...

# %%
top5freeApps = df[df['Type'] == 'Free'].sort_values(by='Installs',ascending=False).head(5)

# %%
top5freeApps
# Out:
#                  App            Category  Rating   Reviews     Size  \
# 3523    Google Drive        PRODUCTIVITY     4.4   2731211      NaN
# 9844     Google News  NEWS_AND_MAGAZINES     3.9    878065  13000.0
# 2808   Google Photos         PHOTOGRAPHY     4.5  10858556      NaN
# 1654  Subway Surfers                GAME     4.5  27722264  76000.0
# 2853   Google Photos         PHOTOGRAPHY     4.5  10858538      NaN
#
#         Installs  Type  Price Content Rating            Genres Last Updated  \
# 3523  1000000000  Free    0.0       Everyone      Productivity   2018-08-06
# 9844  1000000000  Free    0.0           Teen  News & Magazines   2018-08-01
# 2808  1000000000  Free    0.0       Everyone       Photography   2018-08-06
# 1654  1000000000  Free    0.0   Everyone 10+            Arcade   2018-07-12
# 2853  1000000000  Free    0.0       Everyone       Photography   2018-08-06
#
#              Current Ver         Android Ver  day  month  year
# ...
